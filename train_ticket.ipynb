# %%
# !nvidia-smi
# Out:
# Mon Mar 28 23:32:30 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   33C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Mon_Oct_12_20:09:46_PDT_2020
# Cuda compilation tools, release 11.1, V11.1.105
# Build cuda_11.1.TC455_06.29190527_0

# %%
# !unzip "/content/drive/MyDrive/MC_OCR/train_tickets.zip" -d "/content/"

# %%
# !rm -rf "/content/__MACOSX"

# %%
import os
os.chdir('/content/drive/MyDrive/MC_OCR/PICK-pytorch')

# %%
# ! pip install -r requirements.txt

# %%
with open('/content/drive/MyDrive/MC_OCR/PICK-pytorch/utils/keys_empty.txt', 'w') as fp:
    pass

# %%
import torch
torch.__version__
# Out:
# '1.5.1'

# %%
! CUDA_VISIBLE_DEVICES=0 python3 -m torch.distributed.launch --nnode=1 --node_rank=0 --nproc_per_node=1 \
--master_addr=127.0.0.1 --master_port=5555 \
train.py \
-c config_ticket.json \
--local_world_size 1 \
--batch_size 6 \
# --resume /content/drive/MyDrive/MC_OCR/PICK-pytorch/saved/models/PICK_Ticket/test_0328_115743/checkpoint-epoch30.pth \
# --lr 1e-5
# Out:
# Streaming output truncated to the last 5000 lines.
# [2022-03-29 05:20:04,717 - trainer - INFO] - Train Epoch:[19/100] Step:[10/308] Total Loss: 11.436168 GL_Loss: 0.121918 CRF_Loss: 11.314250
# [2022-03-29 05:20:14,633 - trainer - INFO] - Train Epoch:[19/100] Step:[20/308] Total Loss: 14.001767 GL_Loss: 0.110999 CRF_Loss: 13.890768
# [2022-03-29 05:20:24,550 - trainer - INFO] - Train Epoch:[19/100] Step:[30/308] Total Loss: 2.052204 GL_Loss: 0.105040 CRF_Loss: 1.947164
# [2022-03-29 05:20:34,497 - trainer - INFO] - Train Epoch:[19/100] Step:[40/308] Total Loss: 0.680190 GL_Loss: 0.109491 CRF_Loss: 0.570699
# [2022-03-29 05:20:44,367 - trainer - INFO] - Train Epoch:[19/100] Step:[50/308] Total Loss: 0.785837 GL_Loss: 0.110015 CRF_Loss: 0.675822
# [2022-03-29 05:20:49,793 - trainer - INFO] - [Step Validation] Epoch:[19/100] Step:[50/308]
# +---------------------+----------+----------+----------+----------+
# | name                |      mEP |      mER |      mEF |      mEA |
# ...
