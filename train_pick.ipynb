# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# !rm -rf /content/mc_ocr_train_filtered

# %%
# !unzip "/content/drive/MyDrive/MC_OCR/mc_ocr_train_filtered.zip" -d "/content/"

# %%
# !nvidia-smi
# Out:
# Fri Mar 25 09:15:40 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P0    27W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Mon_Oct_12_20:09:46_PDT_2020
# Cuda compilation tools, release 11.1, V11.1.105
# Build cuda_11.1.TC455_06.29190527_0

# %%
import os
os.chdir('/content/drive/MyDrive/MC_OCR/PICK-pytorch')

# %%
# ! pip install -r requirements.txt
# !pip install torch==1.5.1+cu101 torchvision==0.6.1+cu101 -f https://download.pytorch.org/whl/torch_stable.html

# %%
import torch
torch.__version__
# Out:
# '1.5.1'

# %%
! CUDA_VISIBLE_DEVICES=0 python3 -m torch.distributed.launch --nnode=1 --node_rank=0 --nproc_per_node=1 \
--master_addr=127.0.0.1 --master_port=5555 \
train.py -c config.json --local_world_size 1 \
--resume /content/drive/MyDrive/MC_OCR/PICK-pytorch/saved/models/PICK_Default/test_0324_232957/checkpoint-epoch60.pth \
# --lr 1e-5
# Out:
# Streaming output truncated to the last 5000 lines.
# [2022-03-25 09:52:40,377 - trainer - INFO] - Train Epoch:[64/100] Step:[10/499] Total Loss: 0.361832 GL_Loss: 0.157975 CRF_Loss: 0.203857
# [2022-03-25 09:52:52,343 - trainer - INFO] - Train Epoch:[64/100] Step:[20/499] Total Loss: 0.430317 GL_Loss: 0.224141 CRF_Loss: 0.206177
# [2022-03-25 09:53:04,048 - trainer - INFO] - Train Epoch:[64/100] Step:[30/499] Total Loss: 3.354282 GL_Loss: 0.162265 CRF_Loss: 3.192017
# [2022-03-25 09:53:16,865 - trainer - INFO] - Train Epoch:[64/100] Step:[40/499] Total Loss: 0.303641 GL_Loss: 0.191580 CRF_Loss: 0.112061
# [2022-03-25 09:53:30,059 - trainer - INFO] - Train Epoch:[64/100] Step:[50/499] Total Loss: 0.414335 GL_Loss: 0.153593 CRF_Loss: 0.260742
# [2022-03-25 09:53:41,306 - trainer - INFO] - [Step Validation] Epoch:[64/100] Step:[50/499]
# +------------+----------+----------+----------+----------+
# | name       |      mEP |      mER |      mEF |      mEA |
# ...
